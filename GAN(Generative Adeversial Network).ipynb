# %% [markdown]
# # Generative Adversial Network(GAN)
#
# <b>GAN</b> is deep learning algorithm to generate realistic images.
#
# Discriminitive VS Generative models:
#
# <b>Discriminitive model</b>
# ![vae.png](attachment:vae.png)
